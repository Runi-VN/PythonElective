# %% [markdown]
# ## Week 6, Exercise 1
#
# ### Create a module containing a class with the following methods:
#
# 1. init(self, url_list)
# 2. download(url,filename) raises NotFoundException when url returns 404
# 3. multi_download(url_list) uses threads to download multiple urls as text and stores filenames as a property
# 4. iter() returns an iterator
# 5. next() returns the next filename (and stops when there are no more)
# 6. urllist_generator() returns a generator to loop through the urls
# 7. avg_vowels(text) - a rough estimate on readability returns average number of vowels in the words of the text
# 8. hardest_read() returns the filename of the text with the highest vowel score (use all the cpu cores on the computer for this work.

# %%
import requests
#import threading
from concurrent.futures import ThreadPoolExecutor
from concurrent.futures import ProcessPoolExecutor
import multiprocessing
import os

#2
class NotFoundException(Exception): #https://stackoverflow.com/questions/1319615/proper-way-to-declare-custom-exceptions-in-modern-python
    def __init(self, *args,**kwargs):
        Exception.__init__(self,*args,**kwargs) #https://github.com/datsoftlyngby/dat4sem2020spring-python/blob/master/03-2%20Exceptions.ipynb

class ex6_module:
    #1
    def __init__(self, url_list:list):
        """
        URLs must be provided as a list []
        """
        this._url_list = url_list
        self._current = -1  # not read yet #5
    
    #2
    def download(self, url, filename):
        """
        Downloads a file??? If error code is 404, raises custom exception.
        Output repository is cwd + '/output/' + filename
        """
        response = requests.get(url)
        if response.status_code == 404:
            raise NotFoundException('Server returned error code 404.')
        #elif response.status_code == 200:
        with open('./output/' + filename, 'wb', encoding=response.encoding) as file_object:
            file_object.write(response.content)   
        #self._url_list.append(url)
        return filename
    #3
    def multi_download(self, url_list:list):
        """
        Downloads multiple files and stores them in local property
        """
        #https://github.com/datsoftlyngby/dat4sem2020spring-python/blob/master/06-4%20Concurrency%20vs%20Paralelism.ipynb
        with ThreadPoolExecutor() as executor:
            result = executor.map(download, url_list)
            self._filenames = list(result)
    #4
    def __iter__(self):
        return self
    
    #5
    def __next__(self):
        self._current += 1
        if self._current < len(self._url_list):
            return self._filenames[current]
        raise StopIteration

    #6
    def urllist_generator(self):
        return (url for url in self._url_list) #generator expression 
    #7
    def avg_vowels(self, text:str):
        vowels = text.lower().count(*'aeiouæøå') #https://stackoverflow.com/a/19967023
        word_count = len(text.split())
        return vowels / word_count
    #8
    #https://github.com/datsoftlyngby/dat4sem2020spring-python/blob/master/06-4%20Concurrency%20vs%20Paralelism.ipynb
    def hardest_read():
        with ProcessPoolExecutor(os.cpu_count()) as executor:
            result = executor.map(avg_vowels,)
