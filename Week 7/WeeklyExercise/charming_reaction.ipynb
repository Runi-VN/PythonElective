# %% [markdown]
# # Showcase of results
#
# ### Exercise 1: Hvor mange brugte biler er der at vælge i mellem?

# %%
import charming_reaction #.py module
ex1_result = charming_reaction.exercise1()
print('Antal brugte biler: ', ex1_result)
# Out:
# Antal brugte biler:30191

# %% [markdown]
# ### Exercise 2: Udskriv alle biler af mærket Ford
#
# *Due to 97 pages I will only show a selection, but you get the idea.*

# %%
charming_reaction.exercise2()
# Out:
# a.dk/ford-fiesta-14-trend-benzin/id-505212249/",
#   "price": "39900"
# }
#
#  11%|█         | 11/100 [00:07<00:56,  1.57it/s]###############
# NEW PAGE:12
# ###############
# {
#   "name": "Ford Mondeo 2,0 TDCi 210 ST-Line stc. aut. Diesel...",
#   "url": "https://www.dba.dk/ford-mondeo-20-tdci-210/id-505192274/",
#   "price": "299999"
# }
#
# {
#   "name": "Ford S-MAX 2,0 EcoBlue ST-Line aut. Diesel aut....",
#   "url": "https://www.dba.dk/ford-s-max-20-ecoblue-st-line/id-505212124/",
#   "price": "385800"
# }
#
# {
#   "name": "Ford Kuga 1,5 SCTi 150 Titanium Benzin model&amp;#229;r...",
#   "url": "https://www.dba.dk/ford-kuga-15-scti-150/id-505212126/",
#   "price": "169900"
# }
#
# {
#   "name": "Ford S-MAX 2,0 TDCi 163 Titanium 7prs Diesel...",
#   "url": "https://www.dba.dk/ford-s-max-20-tdci-163/id-505212234/",
#   "price": "149500"
# }
#
#  12%|█▏        | 12/100 [00:07<00:53,  1.65it/s]###############
# NEW PAGE:13
# ###############
# {
# ...

# %% [markdown]
# ### Exercise 3: Åben de 5 dyreste biler med selenium i decending order og vis dem i et barchart

# %%
import charming_reaction
ex3_result = charming_reaction.exercise3()
print(ex3_result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# E:\Programs\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# E:\Programs\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...
